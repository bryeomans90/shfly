# %% [markdown]
# https://github.com/sflydatascience/homework1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import networkx as nx

pd.set_option('display.max_rows', 1000)

# %% [markdown]
# # Explore Online

# %% [markdown]
# #### Basic Data Quality Checks and Summary

# %%
online = pd.read_csv('data/online.csv')

online['dt'] = pd.to_datetime(online['dt'])
online['event1'] = online['event1'].fillna(-1)

# %%
online['dt'].describe()
# Out:
# count                  954774
# unique                 942579
# top       2016-03-28 07:16:46
# freq                        4
# first     2016-01-01 00:00:08
# last      2017-12-31 23:58:05
# Name: dt, dtype: object

# %%
online.shape
# Out:
# (954774, 7)

# %%
online[['session', 'dt','event1','event2']].drop_duplicates().shape
# Out:
# (954774, 4)

# %%
online.groupby(
    ['session','category', 'event1', 'event2'], 
    as_index=False
).count()[
     ['session','category', 'event1', 'event2', 'visitor']
]
# Out:
#         session  category  event1  event2  visitor
# 0             2         2    -1.0       9        1
# 1             3         2    -1.0       8        1
# 2             6         2    -1.0       9        1
# 3             9         2    -1.0       3        1
# 4             9         2    -1.0       7        1
# ...         ...       ...     ...     ...      ...
# 954769  3750690         3    11.0      10        1
# 954770  3750694         3    -1.0      10        1
# 954771  3750721         3    -1.0      10        1
# 954772  3750758         3    -1.0      10        1
# 954773  3750761         3    -1.0      10        1
#
# [954774 rows x 5 columns]

# %%
online.head()
# Out:
#    session  visitor                  dt  custno  category  event1  event2
# 0   419542   140970 2016-09-16 05:03:23    3840         1    -1.0       1
# 1  3030130    14501 2017-11-13 04:58:12   70400         1    -1.0       1
# 2  2638740   419353 2017-05-24 16:10:38   21248         1    -1.0       1
# 3   880408    90673 2017-10-28 13:42:38   39168         1    -1.0       1
# 4  2612179   191542 2016-05-17 06:30:32   47616         1    -1.0       1

# %%
online.isna().sum()
# Out:
# session     0
# visitor     0
# dt          0
# custno      0
# category    0
# event1      0
# event2      0
# dtype: int64

# %%
online.isna().sum()
# Out:
# session     0
# visitor     0
# dt          0
# custno      0
# category    0
# event1      0
# event2      0
# dtype: int64

# %% [markdown]
# #### Number of Sessions by Day of Week

# %%
online.head()
# Out:
#    session  visitor                  dt  custno  category  event1  event2
# 0   419542   140970 2016-09-16 05:03:23    3840         1    -1.0       1
# 1  3030130    14501 2017-11-13 04:58:12   70400         1    -1.0       1
# 2  2638740   419353 2017-05-24 16:10:38   21248         1    -1.0       1
# 3   880408    90673 2017-10-28 13:42:38   39168         1    -1.0       1
# 4  2612179   191542 2016-05-17 06:30:32   47616         1    -1.0       1

# %%
online['DOW'] = online['dt'].dt.dayofweek
unique_sessions = online[['DOW', 'session']].drop_duplicates()
sessions_by_dow = unique_sessions.groupby('DOW').count()

# %%
sessions_by_dow.index = [
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
]

# %%
plt.title('Number of Unique Sessions by Day of Week')
plt.bar(sessions_by_dow.index, sessions_by_dow['session'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Number of Sessions By Day

# %%
online['date'] = online['dt'].dt.date
unique_sessions = online[['date', 'session']].drop_duplicates()
sessions_per_day = unique_sessions.groupby('date').count()

# %%
plt.plot(sessions_per_day)
plt.title('Number of Unique Sessions by Date')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Distince Customers

# %% [markdown]
# #### Evaluate Event 1

# %%
online['n'] = 1

# %%
event_1_counts = online.groupby('event1').count()['session']

# %%
plt.bar(event_1_counts.index, event_1_counts)
plt.title('Event 1 Counts by Type')
plt.xlabel('Event 1 Counts by Type')
plt.show()

# %%
online
# Out:
#         session  visitor                  dt  custno  category  event1  \
# 0        419542   140970 2016-09-16 05:03:23    3840         1    -1.0
# 1       3030130    14501 2017-11-13 04:58:12   70400         1    -1.0
# 2       2638740   419353 2017-05-24 16:10:38   21248         1    -1.0
# 3        880408    90673 2017-10-28 13:42:38   39168         1    -1.0
# 4       2612179   191542 2016-05-17 06:30:32   47616         1    -1.0
# ...         ...      ...                 ...     ...       ...     ...
# 954769  1136918    61351 2017-01-10 18:16:01   25087         3    11.0
# 954770  2400378   226006 2017-07-14 13:46:19   27135         3    11.0
# 954771  2014765   210713 2017-08-19 14:47:11   35583         3    11.0
# 954772  2963482   144530 2016-01-15 15:55:51   41215         3    11.0
# 954773  3401664   259135 2017-05-26 14:46:03   56319         3    11.0
#
#         event2  DOW        date  n
# 0            1    4  2016-09-16  1
# 1            1    0  2017-11-13  1
# 2            1    2  2017-05-24  1
# 3            1    5  2017-10-28  1
# 4            1    1  2016-05-17  1
# ...        ...  ...         ... ..
# 954769      10    1  2017-01-10  1
# 954770      10    4  2017-07-14  1
# 954771      10    5  2017-08-19  1
# 954772      10    4  2016-01-15  1
# 954773      10    4  2017-05-26  1
#
# [954774 rows x 10 columns]

# %% [markdown]
# #### Evaluate Event 2

# %%
event_2_counts = online.groupby('event2').count()['session']

# %%
plt.bar(event_2_counts.index, event_2_counts)
plt.title('Event 2 Counts by Type')
plt.xlabel('Event 2 Counts by Type')
plt.show()

# %% [markdown]
# # Explore order.csv

# %%
order = pd.read_csv('data/order.csv')

# %%
order['prodcat2'].unique().shape
# Out:
# (252,)

# %%
order.head()
# Out:
#    custno   ordno            orderdate  prodcat2  prodcat1  revenue
# 0   18944   64694  2016-11-27 20:57:20       NaN         1    53.30
# 1   18944  114405  2017-04-29 20:18:04       NaN         1     0.10
# 2   18944   28906  2017-04-23 21:31:03       NaN         1   141.66
# 3   36096   62681  2016-02-25 07:16:33       NaN         1    36.82
# 4       1       1  2017-06-12 08:27:59       NaN         1     8.35

# %% [markdown]
# #### Assumptions
#     - Assuming that prodcat2 of 96 is always associated prodcat1 of 7
#         - Assuming that the overlap of with prodcat1 is a data quality issue
#         - Normally I would confirm this with a SME, but elected not to because of time

# %%
def clean_96_overlap(prd_cat1, prd_cat2):
    if prd_cat2 == 96:
        prd_cat1 = 7
    return prd_cat1

def test_clean_96_overlap():
    in_data = [
        [0,1],
        [3,96],
        [7,96]
    ]
    obs = [clean_96_overlap(x[0], x[1]) for x in in_data]
    exp = [0,7,7]
    assert obs == exp

test_clean_96_overlap()

# %%
def prod_cat2_nan_fill(prd_cat1, prd_cat2):
    if np.isnan(prd_cat2):
        return -1*prd_cat1
    else:
        return prd_cat2

def test_prod_cat2_nan_fill():
    in_data = [
        [1,np.nan],
        [2,np.nan],
        [3,199],
        [1,2]
    ]
    obs = [prod_cat2_nan_fill(x[0], x[1]) for x in in_data]
    exp = [-1,-2, 199, 2]
    assert obs == exp, f'obs:{obs}, exp:{exp}'

test_prod_cat2_nan_fill()

# %%
order['prodcat2'] = order[['prodcat1', 'prodcat2']].apply(
    lambda row: prod_cat2_nan_fill(row['prodcat1'], row['prodcat2']), axis=1
)

# %%
order['prodcat1'] = order[['prodcat1', 'prodcat2']].apply(
    lambda row: clean_96_overlap(row['prodcat1'], row['prodcat2']), axis=1
)

# %% [markdown]
# #### Clean Up Dates

# %%
order['orderdate'] = pd.to_datetime(order['orderdate'])
order['order_year_month'] = order['orderdate'].dt.to_period('M')
order['order_year_month'] = order['order_year_month'].apply(lambda dt: dt.to_timestamp())

# %% [markdown]
# #### Determine Date Range

# %%
order['orderdate'].describe()
# Out:
# count                  263278
# unique                 149482
# top       2018-09-10 13:41:30
# freq                       26
# first     2016-01-01 05:05:14
# last      2019-01-02 23:54:58
# Name: orderdate, dtype: object

# %% [markdown]
# #### Orders by Month

# %%
orders_by_month = order.groupby('order_year_month').sum()['revenue']

plt.title('Total Orders by Month')
plt.plot(orders_by_month.index, orders_by_month.values)
plt.xlabel('Month of Order')
plt.ylabel('Total Orders')
plt.show()

# %% [markdown]
# #### Check Primary Key

# %%
order.shape
# Out:
# (263278, 7)

# %%
order
# Out:
#         custno   ordno           orderdate  prodcat2  prodcat1  revenue  \
# 0        18944   64694 2016-11-27 20:57:20      -1.0       1.0    53.30
# 1        18944  114405 2017-04-29 20:18:04      -1.0       1.0     0.10
# 2        18944   28906 2017-04-23 21:31:03      -1.0       1.0   141.66
# 3        36096   62681 2016-02-25 07:16:33      -1.0       1.0    36.82
# 4            1       1 2017-06-12 08:27:59      -1.0       1.0     8.35
# ...        ...     ...                 ...       ...       ...      ...
# 263273    7443   99084 2018-09-23 16:02:08     253.0       1.0     6.67
# 263274    6693    8660 2017-06-08 21:37:34     253.0       1.0   122.98
# 263275   22914   36144 2017-05-12 14:07:18     253.0       1.0   143.34
# 263276   36088   62664 2018-03-11 20:19:18     253.0       1.0    49.75
# 263277     827   34605 2016-01-18 08:34:57     255.0       3.0    63.06
#
#        order_year_month
# 0            2016-11-01
# 1            2017-04-01
# 2            2017-04-01
# 3            2016-02-01
# 4            2017-06-01
# ...                 ...
# 263273       2018-09-01
# 263274       2017-06-01
# 263275       2017-05-01
# 263276       2018-03-01
# 263277       2016-01-01
#
# [263278 rows x 7 columns]

# %%
order[['ordno','prodcat2', 'revenue']].drop_duplicates().shape
# Out:
# (263278, 3)

# %% [markdown]
# #### Distribution of Revenue by Category

# %%
order.groupby('prodcat1').agg('describe')['revenue']
# Out:
#             count       mean        std   min      25%     50%     75%    max
# prodcat1
# 1.0       48672.0  74.880807  43.219422  0.00  37.0700  75.120  112.00  150.0
# 2.0       88684.0  75.208527  43.299121  0.00  37.7600  75.255  112.62  150.0
# 3.0       44005.0  74.751113  43.193123  0.01  37.3400  74.620  112.00  150.0
# 4.0       46681.0  74.653734  43.349344  0.00  37.1400  74.550  112.11  150.0
# 5.0       11180.0  75.676608  43.065655  0.00  38.7975  75.685  112.90  150.0
# 7.0       24056.0  74.620874  43.418959  0.01  36.8400  74.165  112.22  150.0

# %%
order['revenue'].hist()
plt.title('Histogram of Revenue Values')
plt.xlabel('Revenue in $')
plt.show()

# %% [markdown]
# #### Orders of Prodcat1 by date

# %%
orders_by_date_and_cat1_long = order.groupby(
    ['order_year_month', 'prodcat1'], as_index=False
).count()[
    ['order_year_month', 'prodcat1', 'ordno']
]

# %%
orders_by_date_and_cat1 = orders_by_date_and_cat1_long.pivot(
    index='order_year_month', columns='prodcat1', values='ordno'
)

# %%
for i in [1,2,3,4,5,7]:
    plt.plot(
        orders_by_date_and_cat1.index, 
        orders_by_date_and_cat1[i], 
        label=f'Category {i} Orders',
        color='black'
    )
    plt.title(f'Total Orders for Category {i}')
    plt.xticks(rotation=45)
    plt.ylabel('Total Orders')
    plt.xlabel('Date of Order')
    plt.vlines([
        pd.to_datetime('12-25-2016'), pd.to_datetime('12-25-2017'), pd.to_datetime('12-25-2018')
    ],0,5000, colors='Green', label='Xmas')
    plt.vlines([
        pd.to_datetime('2-14-2016'), pd.to_datetime('2-14-2017'), pd.to_datetime('2-14-2018')
    ],0,5000, colors='red', label='Valentines Day')
    plt.vlines([
        pd.to_datetime('11-24-2016'), pd.to_datetime('11-23-2017'), pd.to_datetime('11-22-2018')
    ],0,5000, colors='Orange', label='Thanksgiving')
    plt.ylim(0,5000)
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# # Correlations
# - It looks like there aren't that many interesting correlations at the category level

# %%
import seaborn as sns

# %%
order['n'] = 1
prdcat1_orders = order[['ordno', 'prodcat1', 'n']].drop_duplicates()
cat1_purchases_by_order = prdcat1_orders.pivot('ordno', 'prodcat1','n').fillna(0)
cat1_corr = cat1_purchases_by_order.corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.triu(np.ones_like(cat1_corr, dtype=np.bool))

# %%
sns.heatmap(cat1_corr,center=0,mask=mask,
            vmax=.3, vmin=-.3,cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # Pair-wise Directed Graph of Items

# %% [markdown]
# ## Get Edge Data

# %% [markdown]
# #### Get counts from each order

# %%
order['n'] = 1
prdcat2_orders = order[['ordno', 'prodcat2', 'n']].drop_duplicates()
purchases_by_order = prdcat2_orders.pivot('ordno', 'prodcat2','n').fillna(0)

# %% [markdown]
# #### Get Pairwise Association Rules
#     - Would have created even more association rules with a lower min_support, but my Desktop ran out of RAM

# %%
itemsets = apriori(purchases_by_order, min_support=0.0008, use_colnames=True)
rules = association_rules(itemsets, metric="lift", min_threshold=1)
rules['n_before_after'] = rules['antecedents'].apply(len) + rules['consequents'].apply(len)
one2one_rules = rules[rules['n_before_after'] == 2].copy()

# %% [markdown]
# #### Clean up Data

# %%
def clean_association_rules(raw_value):
    return list(raw_value)[0]

one2one_rules['antecedents'] = one2one_rules['antecedents'].apply(clean_association_rules).astype(int)
one2one_rules['consequents'] = one2one_rules['consequents'].apply(clean_association_rules).astype(int)

one2one_rules.sort_values('lift', ascending =False)
# Out:
#      antecedents  consequents  antecedent support  consequent support  \
# 229           93          138            0.004976            0.001757
# 228          138           93            0.001757            0.004976
# 95            67           10            0.002572            0.003801
# 94            10           67            0.003801            0.002572
# 199           94           28            0.001944            0.031934
# 198           28           94            0.031934            0.001944
# 173           39           20            0.015503            0.007220
# 172           20           39            0.007220            0.015503
# 221           54           58            0.007274            0.017326
# 220           58           54            0.017326            0.007274
# 140          213           14            0.006138            0.028367
# 141           14          213            0.028367            0.006138
# 74            26            6            0.001777            0.035955
# 75             6           26            0.035955            0.001777
# 170           20           38            0.007220            0.043743
# 171           38           20            0.043743            0.007220
# 166           18           85            0.018395            0.006412
# 167           85           18            0.006412            0.018395
# 160           18           59            0.018395            0.013799
# 161           59           18            0.013799            0.018395
# 163           69           18            0.004849            0.018395
# 162           18           69            0.018395            0.004849
# 9             35            2            0.004909            0.034378
# 8              2           35            0.034378            0.004909
# 124           12           14            0.012624            0.028367
# 125           14           12            0.028367            0.012624
# 145           54           16            0.007274            0.089856
# 144           16           54            0.089856            0.007274
# 131           12          107            0.012624            0.011168
# 130          107           12            0.011168            0.012624
# 120          169           11            0.002839            0.089462
# 121           11          169            0.089462            0.002839
# 127           12           40            0.012624            0.008964
# 126           40           12            0.008964            0.012624
# 159           58           18            0.017326            0.018395
# 158           18           58            0.018395            0.017326
# 104           40           11            0.008964            0.089462
# 105           11           40            0.089462            0.008964
# 155           85           16            0.006412            0.089856
# 154           16           85            0.089856            0.006412
# 117          149           11            0.002966            0.089462
# 116           11          149            0.089462            0.002966
# 225           78           69            0.055658            0.004849
# 224           69           78            0.004849            0.055658
# 97            12           11            0.012624            0.089462
# 96            11           12            0.089462            0.012624
# 148           16           59            0.089856            0.013799
# 149           59           16            0.013799            0.089856
# 115           11          138            0.089462            0.001757
# 114          138           11            0.001757            0.089462
# 142           16           18            0.089856            0.018395
# 143           18           16            0.018395            0.089856
# 151           69           16            0.004849            0.089856
# 150           16           69            0.089856            0.004849
# 108           89           11            0.085254            0.089462
# 109           11           89            0.089462            0.085254
# 113          107           11            0.011168            0.089462
# 112           11          107            0.089462            0.011168
# 101           19           11            0.006185            0.089462
# 100           11           19            0.089462            0.006185
# 169           19           89            0.006185            0.085254
# 168           89           19            0.085254            0.006185
# 164           18           78            0.018395            0.055658
# 165           78           18            0.055658            0.018395
# 146           16           58            0.089856            0.017326
# 147           58           16            0.017326            0.089856
# 153           78           16            0.055658            0.089856
# 152           16           78            0.089856            0.055658
# 156           18           54            0.018395            0.007274
# 157           54           18            0.007274            0.018395
# 63             5           42            0.086396            0.015222
# 62            42            5            0.015222            0.086396
# 110           11           93            0.089462            0.004976
# 111           93           11            0.004976            0.089462
# 65             5           91            0.086396            0.002164
# 64            91            5            0.002164            0.086396
# 61             5           35            0.086396            0.004909
# 60            35            5            0.004909            0.086396
# 43             4           35            0.105452            0.004909
# 42            35            4            0.004909            0.105452
# 39             7            4            0.015309            0.105452
# 38             4            7            0.105452            0.015309
# 119          165           11            0.001763            0.089462
# 118           11          165            0.089462            0.001763
# 122           11          213            0.089462            0.006138
# 123          213           11            0.006138            0.089462
# 180           25           51            0.031840            0.005330
# 181           51           25            0.005330            0.031840
# 45             4           42            0.105452            0.015222
# 44            42            4            0.015222            0.105452
# 49             4           91            0.105452            0.002164
# 48            91            4            0.002164            0.105452
# 128           89           12            0.085254            0.012624
# 129           12           89            0.012624            0.085254
# 83             7           42            0.015309            0.015222
# 82            42            7            0.015222            0.015309
# 37             5            4            0.086396            0.105452
# 36             4            5            0.105452            0.086396
# 212           42          110            0.015222            0.026363
# 213          110           42            0.026363            0.015222
# 216           43           77            0.016017            0.010694
# 217           77           43            0.010694            0.016017
# 59             7            5            0.015309            0.086396
# 58             5            7            0.086396            0.015309
# 214           50           43            0.016631            0.016017
# 215           43           50            0.016017            0.016631
# 99            14           11            0.028367            0.089462
# 98            11           14            0.089462            0.028367
# 196           27          119            0.023584            0.017146
# 197          119           27            0.017146            0.023584
# 219          119           45            0.017146            0.015730
# 218           45          119            0.015730            0.017146
# 222           54           78            0.007274            0.055658
# 223           78           54            0.055658            0.007274
# 70           195            5            0.002378            0.086396
# 71             5          195            0.086396            0.002378
# 132           16           13            0.089856            0.090551
# 133           13           16            0.090551            0.089856
# 204           45           30            0.015730            0.028120
# 205           30           45            0.028120            0.015730
# 7              7            2            0.015309            0.034378
# 6              2            7            0.034378            0.015309
# 226           89          213            0.085254            0.006138
# 227          213           89            0.006138            0.085254
# 41             4           10            0.105452            0.003801
# 40            10            4            0.003801            0.105452
# 193           45           27            0.015730            0.023584
# 192           27           45            0.023584            0.015730
# 191           27           43            0.023584            0.016017
# 190           43           27            0.016017            0.023584
# 136           13           54            0.090551            0.007274
# 137           54           13            0.007274            0.090551
# 202           43           30            0.016017            0.028120
# 203           30           43            0.028120            0.016017
# 57             4          195            0.105452            0.002378
# 56           195            4            0.002378            0.105452
# 103           21           11            0.006051            0.089462
# 102           11           21            0.089462            0.006051
# 134           18           13            0.018395            0.090551
# 135           13           18            0.090551            0.018395
# 47             4           67            0.105452            0.002572
# 46            67            4            0.002572            0.105452
# 189           30           27            0.028120            0.023584
# 188           27           30            0.023584            0.028120
# 231          119           96            0.017146            0.023498
# 230           96          119            0.023498            0.017146
# 177           43           25            0.016017            0.031840
# 176           25           43            0.031840            0.016017
# 207           30           50            0.028120            0.016631
# 206           50           30            0.016631            0.028120
# 185          119           25            0.017146            0.031840
# 184           25          119            0.031840            0.017146
# 2              2            4            0.034378            0.105452
# 3              4            2            0.105452            0.034378
# 55             4          180            0.105452            0.003006
# 54           180            4            0.003006            0.105452
# 139           13           69            0.090551            0.004849
# 138           69           13            0.004849            0.090551
# 14             3            4            0.273055            0.105452
# 15             4            3            0.105452            0.273055
# 0              2            3            0.034378            0.273055
# 1              3            2            0.273055            0.034378
# 107           11           41            0.089462            0.007721
# 106           41           11            0.007721            0.089462
# 18             3            7            0.273055            0.015309
# 19             7            3            0.015309            0.273055
# 11            42            2            0.015222            0.034378
# 10             2           42            0.034378            0.015222
# 23            35            3            0.004909            0.273055
# 22             3           35            0.273055            0.004909
# 67           110            5            0.026363            0.086396
# 66             5          110            0.086396            0.026363
# 5              5            2            0.086396            0.034378
# 4              2            5            0.034378            0.086396
# 17             5            3            0.086396            0.273055
# 16             3            5            0.273055            0.086396
# 208           30          119            0.028120            0.017146
# 209          119           30            0.017146            0.028120
# 78            43            6            0.016017            0.035955
# 79             6           43            0.035955            0.016017
# 25             3           42            0.273055            0.015222
# 24            42            3            0.015222            0.273055
# 175           27           25            0.023584            0.031840
# 174           25           27            0.031840            0.023584
# 29            91            3            0.002164            0.273055
# 28             3           91            0.273055            0.002164
# 21             3           10            0.273055            0.003801
# 20            10            3            0.003801            0.273055
# 194           96           27            0.023498            0.023584
# 195           27           96            0.023584            0.023498
# 179           50           25            0.016631            0.031840
# 178           25           50            0.031840            0.016631
# 27             3           67            0.273055            0.002572
# 26            67            3            0.002572            0.273055
# 52           147            4            0.008944            0.105452
# 53             4          147            0.105452            0.008944
# 34             3          195            0.273055            0.002378
# 35           195            3            0.002378            0.273055
# 186           27           28            0.023584            0.031934
# 187           28           27            0.031934            0.023584
# 92             9           51            0.084566            0.005330
# 93            51            9            0.005330            0.084566
# 68           147            5            0.008944            0.086396
# 69             5          147            0.086396            0.008944
# 76            30            6            0.028120            0.035955
# 77             6           30            0.035955            0.028120
# 50             4          110            0.105452            0.026363
# 51           110            4            0.026363            0.105452
# 31           110            3            0.026363            0.273055
# 30             3          110            0.273055            0.026363
# 33           180            3            0.003006            0.273055
# 32             3          180            0.273055            0.003006
# 183           25           96            0.031840            0.023498
# 182           96           25            0.023498            0.031840
# 12             2          110            0.034378            0.026363
# 13           110            2            0.026363            0.034378
# 201          110           28            0.026363            0.031934
# 200           28          110            0.031934            0.026363
# 87            43            9            0.016017            0.084566
# 86             9           43            0.084566            0.016017
# 81             6           96            0.035955            0.023498
# 80            96            6            0.023498            0.035955
# 211           38           96            0.043743            0.023498
# 210           96           38            0.023498            0.043743
# 84             9           30            0.084566            0.028120
# 85            30            9            0.028120            0.084566
# 72            25            6            0.031840            0.035955
# 73             6           25            0.035955            0.031840
# 88             9           44            0.084566            0.010994
# 89            44            9            0.010994            0.084566
# 90             9           50            0.084566            0.016631
# 91            50            9            0.016631            0.084566
#
#       support  confidence        lift  leverage  conviction  n_before_after
# 229  0.001363    0.273826  155.879593  0.001354    1.374660               2
# 228  0.001363    0.775665  155.879593  0.001354    4.435446               2
# 95   0.001229    0.477922  125.752302  0.001219    1.908143               2
# 94   0.001229    0.323374  125.752302  0.001219    1.474122               2
# 199  0.001830    0.941581   29.485598  0.001768   16.571019               2
# 198  0.001830    0.057310   29.485598  0.001768    1.058732               2
# 173  0.002485    0.160276   22.197968  0.002373    1.182269               2
# 172  0.002485    0.344126   22.197968  0.002373    1.501046               2
# 221  0.002418    0.332415   19.185885  0.002292    1.471983               2
# 220  0.002418    0.139553   19.185885  0.002292    1.153733               2
# 140  0.003273    0.533188   18.796173  0.003099    2.081424               2
# 141  0.003273    0.115376   18.796173  0.003099    1.123484               2
# 74   0.001109    0.624060   17.356941  0.001045    2.564361               2
# 75   0.001109    0.030838   17.356941  0.001045    1.029986               2
# 170  0.004428    0.613321   14.021160  0.004113    2.473001               2
# 171  0.004428    0.101237   14.021160  0.004113    1.104607               2
# 166  0.001329    0.072259   11.269095  0.001211    1.070975               2
# 167  0.001329    0.207292   11.269095  0.001211    1.238293               2
# 160  0.002859    0.155410   11.262132  0.002605    1.167668               2
# 161  0.002859    0.207164   11.262132  0.002605    1.238093               2
# 163  0.000955    0.196970   10.707956  0.000866    1.222376               2
# 162  0.000955    0.051924   10.707956  0.000866    1.049654               2
# 9    0.001456    0.296599    8.627523  0.001287    1.372789               2
# 8    0.001456    0.042355    8.627523  0.001287    1.039102               2
# 124  0.003012    0.238624    8.412084  0.002654    1.276155               2
# 125  0.003012    0.106193    8.412084  0.002654    1.104686               2
# 145  0.005330    0.732782    8.155057  0.004676    3.406002               2
# 144  0.005330    0.059318    8.155057  0.004676    1.055326               2
# 131  0.001129    0.089418    8.006814  0.000988    1.085934               2
# 130  0.001129    0.101077    8.006814  0.000988    1.098399               2
# 120  0.001937    0.682353    7.627284  0.001683    2.866508               2
# 121  0.001937    0.021651    7.627284  0.001683    1.019229               2
# 127  0.000862    0.068254    7.614590  0.000748    1.063634               2
# 126  0.000862    0.096125    7.614590  0.000748    1.092382               2
# 159  0.002425    0.139938    7.607533  0.002106    1.141320               2
# 158  0.002425    0.131808    7.607533  0.002106    1.131863               2
# 104  0.006085    0.678838    7.587989  0.005283    2.835132               2
# 105  0.006085    0.068016    7.587989  0.005283    1.063362               2
# 155  0.004281    0.667708    7.430855  0.003705    2.738991               2
# 154  0.004281    0.047647    7.430855  0.003705    1.043298               2
# 117  0.001964    0.662162    7.401593  0.001698    2.695192               2
# 116  0.001964    0.021950    7.401593  0.001698    1.019411               2
# 225  0.001997    0.035881    7.399533  0.001727    1.032187               2
# 224  0.001997    0.411846    7.399533  0.001727    1.605602               2
# 97   0.008249    0.653439    7.304088  0.007120    2.627354               2
# 96   0.008249    0.092205    7.304088  0.007120    1.087665               2
# 148  0.009010    0.100275    7.266639  0.007770    1.096113               2
# 149  0.009010    0.652953    7.266639  0.007770    2.622534               2
# 115  0.001122    0.012543    7.140265  0.000965    1.010923               2
# 114  0.001122    0.638783    7.140265  0.000965    2.520752               2
# 142  0.011622    0.129339    7.031327  0.009969    1.127426               2
# 143  0.011622    0.631808    7.031327  0.009969    2.471929               2
# 151  0.003006    0.619835    6.898074  0.002570    2.394074               2
# 150  0.003006    0.033450    6.898074  0.002570    1.029590               2
# 108  0.051945    0.609292    6.810612  0.044318    2.330480               2
# 109  0.051945    0.580633    6.810612  0.044318    2.181254               2
# 113  0.006779    0.607057    6.785636  0.005780    2.317229               2
# 112  0.006779    0.075780    6.785636  0.005780    1.069910               2
# 101  0.003734    0.603672    6.747791  0.003180    2.297433               2
# 100  0.003734    0.041735    6.747791  0.003180    1.037098               2
# 169  0.003553    0.574514    6.738837  0.003026    2.149885               2
# 168  0.003553    0.041680    6.738837  0.003026    1.037038               2
# 164  0.006866    0.373275    6.706546  0.005842    1.506788               2
# 165  0.006866    0.123365    6.706546  0.005842    1.119742               2
# 146  0.010299    0.114621    6.615556  0.008743    1.109891               2
# 147  0.010299    0.594449    6.615556  0.008743    2.244214               2
# 153  0.032775    0.588864    6.553400  0.027774    2.213727               2
# 152  0.032775    0.364751    6.553400  0.027774    1.486570               2
# 156  0.000842    0.045752    6.289988  0.000708    1.040323               2
# 157  0.000842    0.115702    6.289988  0.000708    1.110040               2
# 63   0.008175    0.094627    6.216440  0.006860    1.087704               2
# 62   0.008175    0.537078    6.216440  0.006860    1.973557               2
# 110  0.002712    0.030312    6.091589  0.002267    1.026128               2
# 111  0.002712    0.544966    6.091589  0.002267    2.001035               2
# 65   0.001082    0.012524    5.787283  0.000895    1.010491               2
# 64   0.001082    0.500000    5.787283  0.000895    1.827207               2
# 61   0.002445    0.028295    5.763661  0.002020    1.024067               2
# 60   0.002445    0.497959    5.763661  0.002020    1.819780               2
# 43   0.002939    0.027869    5.676875  0.002421    1.023618               2
# 42   0.002939    0.598639    5.676875  0.002421    2.228788               2
# 39   0.009104    0.594677    5.639301  0.007489    2.207000               2
# 38   0.009104    0.086331    5.639301  0.007489    1.077733               2
# 119  0.000888    0.503788    5.631298  0.000731    1.834977               2
# 118  0.000888    0.009930    5.631298  0.000731    1.008248               2
# 122  0.003059    0.034194    5.570713  0.002510    1.029049               2
# 123  0.003059    0.498368    5.570713  0.002510    1.815150               2
# 180  0.000922    0.028949    5.431280  0.000752    1.024323               2
# 181  0.000922    0.172932    5.431280  0.000752    1.170593               2
# 45   0.008596    0.081518    5.355231  0.006991    1.072179               2
# 44   0.008596    0.564721    5.355231  0.006991    2.055115               2
# 49   0.001202    0.011401    5.268312  0.000974    1.009344               2
# 48   0.001202    0.555556    5.268312  0.000974    2.012732               2
# 128  0.005464    0.064086    5.076634  0.004387    1.054987               2
# 129  0.005464    0.432804    5.076634  0.004387    1.612751               2
# 83   0.001135    0.074171    4.872604  0.000902    1.063672               2
# 82   0.001135    0.074594    4.872604  0.000902    1.064064               2
# 37   0.044137    0.510862    4.844485  0.035026    1.828825               2
# 36   0.044137    0.418546    4.844485  0.035026    1.571239               2
# 212  0.001930    0.126810    4.810138  0.001529    1.115034               2
# 213  0.001930    0.073220    4.810138  0.001529    1.062580               2
# 216  0.000822    0.051293    4.796624  0.000650    1.042794               2
# 217  0.000822    0.076827    4.796624  0.000650    1.065871               2
# 59   0.006258    0.408813    4.731836  0.004936    1.545372               2
# 58   0.006258    0.072439    4.731836  0.004936    1.061592               2
# 214  0.001242    0.074699    4.663753  0.000976    1.063419               2
# 215  0.001242    0.077565    4.663753  0.000976    1.066057               2
# 99   0.011789    0.415587    4.645402  0.009251    1.558040               2
# 98   0.011789    0.131775    4.645402  0.009251    1.119103               2
# 196  0.001823    0.077315    4.509311  0.001419    1.065211               2
# 197  0.001823    0.106350    4.509311  0.001419    1.092615               2
# 219  0.001162    0.067783    4.309269  0.000892    1.055839               2
# 218  0.001162    0.073885    4.309269  0.000892    1.061266               2
# 222  0.001717    0.235996    4.240089  0.001312    1.236043               2
# 223  0.001717    0.030841    4.240089  0.001312    1.024317               2
# 70   0.000855    0.359551    4.161641  0.000650    1.426504               2
# 71   0.000855    0.009896    4.161641  0.000650    1.007593               2
# 132  0.033416    0.371887    4.106945  0.025280    1.447908               2
# 133  0.033416    0.369034    4.106945  0.025280    1.442462               2
# 204  0.001650    0.104883    3.729882  0.001207    1.085758               2
# 205  0.001650    0.058670    3.729882  0.001207    1.045616               2
# 7    0.001944    0.126963    3.693136  0.001417    1.106050               2
# 6    0.001944    0.056538    3.693136  0.001417    1.043700               2
# 226  0.001830    0.021467    3.497191  0.001307    1.015665               2
# 227  0.001830    0.298150    3.497191  0.001307    1.303336               2
# 41   0.001356    0.012858    3.383201  0.000955    1.009175               2
# 40   0.001356    0.356766    3.383201  0.000955    1.390704               2
# 193  0.001242    0.078981    3.348848  0.000871    1.060147               2
# 192  0.001242    0.052676    3.348848  0.000871    1.039001               2
# 191  0.001262    0.053526    3.341843  0.000885    1.039630               2
# 190  0.001262    0.078816    3.341843  0.000885    1.059957               2
# 136  0.002177    0.024047    3.305957  0.001519    1.017186               2
# 137  0.002177    0.299357    3.305957  0.001519    1.298021               2
# 202  0.001469    0.091743    3.262590  0.001019    1.070050               2
# 203  0.001469    0.052257    3.262590  0.001019    1.038238               2
# 57   0.000815    0.007727    3.249779  0.000564    1.005391               2
# 56   0.000815    0.342697    3.249779  0.000564    1.360936               2
# 103  0.001750    0.289183    3.232466  0.001209    1.280974               2
# 102  0.001750    0.019561    3.232466  0.001209    1.013779               2
# 134  0.005257    0.285766    3.155864  0.003591    1.273321               2
# 135  0.005257    0.058051    3.155864  0.003591    1.042100               2
# 47   0.000855    0.008107    3.152777  0.000584    1.005581               2
# 46   0.000855    0.332468    3.152777  0.000584    1.340081               2
# 189  0.002077    0.073872    3.132216  0.001414    1.054298               2
# 188  0.002077    0.088077    3.132216  0.001414    1.065748               2
# 231  0.001216    0.070900    3.017316  0.000813    1.051019               2
# 230  0.001216    0.051734    3.017316  0.000813    1.036475               2
# 177  0.001516    0.094662    2.973053  0.001006    1.069391               2
# 176  0.001516    0.047619    2.973053  0.001006    1.033182               2
# 207  0.001383    0.049169    2.956378  0.000915    1.034220               2
# 206  0.001383    0.083133    2.956378  0.000915    1.060001               2
# 185  0.001590    0.092715    2.911904  0.001044    1.067096               2
# 184  0.001590    0.049927    2.911904  0.001044    1.034504               2
# 2    0.010186    0.296289    2.809698  0.006561    1.271186               2
# 3    0.010186    0.096592    2.809698  0.006561    1.068866               2
# 55   0.000888    0.008424    2.802742  0.000571    1.005464               2
# 54   0.000888    0.295556    2.802742  0.000571    1.269863               2
# 139  0.001222    0.013499    2.783697  0.000783    1.008768               2
# 138  0.001222    0.252066    2.783697  0.000783    1.215949               2
# 14   0.078268    0.286637    2.718166  0.049473    1.253986               2
# 15   0.078268    0.742209    2.718166  0.049473    2.819903               2
# 0    0.025368    0.737906    2.702405  0.015981    2.773599               2
# 1    0.025368    0.092904    2.702405  0.015981    1.064520               2
# 107  0.001857    0.020756    2.688115  0.001166    1.013311               2
# 106  0.001857    0.240484    2.688115  0.001166    1.198840               2
# 18   0.011148    0.040826    2.666805  0.006968    1.026603               2
# 19   0.011148    0.728185    2.666805  0.006968    2.674410               2
# 11   0.001322    0.086880    2.527190  0.000799    1.057497               2
# 10   0.001322    0.038469    2.527190  0.000799    1.024177               2
# 23   0.003286    0.669388    2.451474  0.001946    2.198784               2
# 22   0.003286    0.012035    2.451474  0.001946    1.007212               2
# 67   0.005323    0.201926    2.337200  0.003046    1.144760               2
# 66   0.005323    0.061616    2.337200  0.003046    1.037567               2
# 5    0.006853    0.079320    2.307267  0.003883    1.048813               2
# 4    0.006853    0.199339    2.307267  0.003883    1.141062               2
# 17   0.054035    0.625435    2.290507  0.030444    1.940770               2
# 16   0.054035    0.197891    2.290507  0.030444    1.139003               2
# 208  0.001089    0.038717    2.258139  0.000607    1.022440               2
# 209  0.001089    0.063498    2.258139  0.000607    1.037777               2
# 78   0.001282    0.080067    2.226890  0.000707    1.047952               2
# 79   0.001282    0.035668    2.226890  0.000707    1.020378               2
# 25   0.008897    0.032582    2.140472  0.004740    1.017945               2
# 24   0.008897    0.584467    2.140472  0.004740    1.749427               2
# 175  0.001590    0.067403    2.116924  0.000839    1.038133               2
# 174  0.001590    0.049927    2.116924  0.000839    1.027726               2
# 29   0.001236    0.570988    2.091107  0.000645    1.694461               2
# 28   0.001236    0.004525    2.091107  0.000645    1.002372               2
# 21   0.002164    0.007925    2.085366  0.001126    1.004158               2
# 20   0.002164    0.569420    2.085366  0.001126    1.688292               2
# 194  0.001109    0.047186    2.000717  0.000555    1.024770               2
# 195  0.001109    0.047012    2.000717  0.000555    1.024675               2
# 179  0.001029    0.061847    1.942439  0.000499    1.031986               2
# 178  0.001029    0.032305    1.942439  0.000499    1.016197               2
# 27   0.001309    0.004794    1.864425  0.000607    1.002234               2
# 26   0.001309    0.509091    1.864425  0.000607    1.480814               2
# 52   0.001757    0.196415    1.862598  0.000814    1.113196               2
# 53   0.001757    0.016658    1.862598  0.000814    1.007845               2
# 34   0.001176    0.004305    1.810557  0.000526    1.001936               2
# 35   0.001176    0.494382    1.810557  0.000526    1.437735               2
# 186  0.001363    0.057774    1.809193  0.000609    1.027425               2
# 187  0.001363    0.042669    1.809193  0.000609    1.019935               2
# 92   0.000808    0.009557    1.793022  0.000357    1.004268               2
# 93   0.000808    0.151629    1.793022  0.000357    1.079049               2
# 68   0.001376    0.153846    1.780702  0.000603    1.079713               2
# 69   0.001376    0.015926    1.780702  0.000603    1.007095               2
# 76   0.001790    0.063658    1.770514  0.000779    1.029587               2
# 77   0.001790    0.049786    1.770514  0.000779    1.022802               2
# 50   0.004515    0.042817    1.624140  0.001735    1.017190               2
# 51   0.004515    0.171269    1.624140  0.001735    1.079419               2
# 31   0.011188    0.424373    1.554166  0.003989    1.262875               2
# 30   0.011188    0.040973    1.554166  0.003989    1.015234               2
# 33   0.001202    0.400000    1.464905  0.000382    1.211575               2
# 32   0.001202    0.004403    1.464905  0.000382    1.001404               2
# 183  0.001089    0.034193    1.455183  0.000341    1.011074               2
# 182  0.001089    0.046333    1.455183  0.000341    1.015197               2
# 12   0.001182    0.034389    1.304437  0.000276    1.008312               2
# 13   0.001182    0.044844    1.304437  0.000276    1.010957               2
# 201  0.001082    0.041044    1.285287  0.000240    1.009500               2
# 200  0.001082    0.033884    1.285287  0.000240    1.007785               2
# 87   0.001670    0.104254    1.232804  0.000315    1.021979               2
# 86   0.001670    0.019746    1.232804  0.000315    1.003804               2
# 81   0.000989    0.027494    1.170072  0.000144    1.004109               2
# 80   0.000989    0.042069    1.170072  0.000144    1.006383               2
# 211  0.001196    0.027332    1.163197  0.000168    1.003943               2
# 210  0.001196    0.050881    1.163197  0.000168    1.007521               2
# 84   0.002759    0.032620    1.160035  0.000381    1.004652               2
# 85   0.002759    0.098100    1.160035  0.000381    1.015006               2
# 72   0.001236    0.038808    1.079377  0.000091    1.002969               2
# 73   0.001236    0.034367    1.079377  0.000091    1.002617               2
# 88   0.000989    0.011689    1.063249  0.000059    1.000704               2
# 89   0.000989    0.089915    1.063249  0.000059    1.005877               2
# 90   0.001483    0.017534    1.054282  0.000076    1.000919               2
# 91   0.001483    0.089157    1.054282  0.000076    1.005040               2

# %%
one2one_rules.shape
# Out:
# (232, 10)

# %% [markdown]
# ## Get Node Data

# %%
order.head()
# Out:
#    custno   ordno           orderdate  prodcat2  prodcat1  revenue  \
# 0   18944   64694 2016-11-27 20:57:20      -1.0       1.0    53.30
# 1   18944  114405 2017-04-29 20:18:04      -1.0       1.0     0.10
# 2   18944   28906 2017-04-23 21:31:03      -1.0       1.0   141.66
# 3   36096   62681 2016-02-25 07:16:33      -1.0       1.0    36.82
# 4       1       1 2017-06-12 08:27:59      -1.0       1.0     8.35
#
#   order_year_month  n
# 0       2016-11-01  1
# 1       2017-04-01  1
# 2       2017-04-01  1
# 3       2016-02-01  1
# 4       2017-06-01  1

# %%
nodes = order.groupby(['prodcat2', 'prodcat1'], as_index=False).count()[['prodcat2','prodcat1','n']]
nodes['log_n_orders'] = np.log2(nodes['n'])

# %% [markdown]
# #### Set Node Colors

# %%
prdcat1_color = {
    1: '#fc4f30',
    2: '#0085CA',
    3: 'green',
    4: 'orange',
    5: 'grey',
    7: '#b19cd9'
}

# %%
nodes['color'] = nodes['prodcat1'].apply(lambda row: prdcat1_color[row])

# %%
assert len(set(nodes['prodcat2'])) == len(nodes['prodcat2'])

# %% [markdown]
# #### Which Products Tend to be Purchased Together
# - Load Edges
# - Load Nodes
# - Visualize

# %% [markdown]
# ## Plot Only Products with an Edge

# %% [markdown]
# #### Filter Out Nodes with No Edges

# %%
connected_items = set(one2one_rules['antecedents']).union(set(one2one_rules['consequents']))
connected_nodes = nodes[nodes['prodcat2'].isin(connected_items)]

# %%
G = nx.from_pandas_edgelist(one2one_rules, 'antecedents', 'consequents', edge_attr ='confidence') 
G.add_nodes_from(connected_nodes['prodcat2'], size=connected_nodes['log_n_orders'])

# %%
layouts = [
    'random_layout',
    'shell_layout',
    'fruchterman_reingold_layout',
    'spectral_layout',
    'kamada_kawai_layout',
    'spring_layout',
    'circular_layout'
]

# %% [markdown]
# #### Key Takeaways
#     - It looks like product category 2 products are pretty highly associated with
#     - There appear to be 2 clusters of products.

# %%
plt.rcParams["figure.figsize"] = (20,20)

for layout in layouts:
    print(layout)
    for i in [1,2,3,4,5,7]:
        plt.plot([0],[0], color=prdcat1_color[i], label=f'Cat {i}')
        
    plt.axis('off')
    plt.legend()
    pos = eval(f'nx.{layout}(G)')
    nx.draw(
        G, with_labels=True, 
        node_color = connected_nodes['color'],
        node_size = connected_nodes['log_n_orders']**2*10,
        width = one2one_rules['confidence']*10
    )
    plt.legend()
    plt.show()
# Out:
# random_layout
# shell_layout
# fruchterman_reingold_layout
# spectral_layout
# kamada_kawai_layout
# spring_layout
# circular_layout

# %% [markdown]
# ## Plot All Products
# - Not very interesteding because most nodes don't have an edge due to limited processing power of my PC

# %%
G = nx.from_pandas_edgelist(one2one_rules, 'antecedents', 'consequents', edge_attr ='confidence') 
G.add_nodes_from(nodes['prodcat2'], size=nodes['log_n_orders'])

# %%
layouts = [
    'fruchterman_reingold_layout'
]

# %%
plt.rcParams["figure.figsize"] = (20,20)

for layout in layouts:
    print(layout)
    for i in [1,2,3,4,5,7]:
        plt.plot([0],[0], color=prdcat1_color[i], label=f'Cat {i}')
        
    plt.axis('off')
    plt.legend()
    pos = eval(f'nx.{layout}(G)')
    nx.draw(
        G, with_labels=True, 
        node_color = nodes['color'],
        node_size = nodes['log_n_orders']**2*10,
        width = one2one_rules['confidence']*10
    )
    plt.legend()
    plt.show()
# Out:
# fruchterman_reingold_layout

# %% [markdown]
# # TODO: Create Associations with only the Top 10% most popular products
